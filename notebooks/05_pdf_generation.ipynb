# %% [markdown]
# # PDF Generation
#
# This notebook renders the generated HTML reports into PDF format using Playwright.
#
# The rendering logic is implemented in `src/pdf_renderer.py`.

# %%
# !python convert_pdf.py
